# %% [markdown]
# <a href="https://colab.research.google.com/github/LagnajeetP/Research2023-2024/blob/main/ModelCreation_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv('coronavirusdatasetprocessed.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (86, 881)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (86, 185)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:15<00:00,  2.75it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 393
# [LightGBM] [Info] Number of data points in the train set: 68, number of used features: 131
# [LightGBM] [Info] Start training from score 4.737326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:16<00:00,  2.60it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 393
# [LightGBM] [Info] Number of data points in the train set: 68, number of used features: 131
# [LightGBM] [Info] Start training from score 4.737326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
predictions_train
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          63133934735877203250327932704749872722994892659...
# KernelRidge                                                                15.44
# DummyRegressor                                                              1.57
# LassoLars                                                                   1.57
# Lasso                                                                       1.57
# ElasticNet                                                                  1.56
# LarsCV                                                                      1.44
# OrthogonalMatchingPursuitCV                                                 1.40
# LassoLarsCV                                                                 1.27
# KNeighborsRegressor                                                         1.19
# HistGradientBoostingRegressor                                               1.18
# LGBMRegressor                                                               1.18
# BayesianRidge                                                               1.16
# NuSVR                                                                       1.14
# GammaRegressor                                                              1.14
# TweedieRegressor                                                            1.14
# SVR                                                                         1.14
# OrthogonalMatchingPursuit                                                   1.09
# AdaBoostRegressor                                                           1.09
# BaggingRegressor                                                            1.08
# PoissonRegressor                                                            1.07
# SGDRegressor                                                                1.07
# RidgeCV                                                                     1.06
# RandomForestRegressor                                                       1.06
# PassiveAggressiveRegressor                                                  1.04
# LassoCV                                                                     1.02
# ElasticNetCV                                                                1.02
# GradientBoostingRegressor                                                   1.02
# HuberRegressor                                                              1.02
# Ridge                                                                       1.02
# MLPRegressor                                                                1.02
# LinearSVR                                                                   1.01
# LinearRegression                                                            1.01
# TransformedTargetRegressor                                                  1.01
# XGBRegressor                                                                1.01
# GaussianProcessRegressor                                                    1.01
# ExtraTreesRegressor                                                         1.01
# ExtraTreeRegressor                                                          1.01
# DecisionTreeRegressor                                                       1.01
#
#                                                                        R-Squared  \
# Model
# Lars                          -1111911089378135845945553205841128612338797877...
# KernelRidge                                                               -24.43
# DummyRegressor                                                              0.00
# LassoLars                                                                   0.00
# Lasso                                                                       0.00
# ElasticNet                                                                  0.01
# LarsCV                                                                      0.23
# OrthogonalMatchingPursuitCV                                                 0.29
# LassoLarsCV                                                                 0.52
# KNeighborsRegressor                                                         0.67
# HistGradientBoostingRegressor                                               0.69
# LGBMRegressor                                                               0.69
# BayesianRidge                                                               0.72
# NuSVR                                                                       0.75
# GammaRegressor                                                              0.75
# TweedieRegressor                                                            0.75
# SVR                                                                         0.75
# OrthogonalMatchingPursuit                                                   0.84
# AdaBoostRegressor                                                           0.85
# BaggingRegressor                                                            0.87
# PoissonRegressor                                                            0.87
# SGDRegressor                                                                0.88
# RidgeCV                                                                     0.89
# RandomForestRegressor                                                       0.90
# PassiveAggressiveRegressor                                                  0.93
# LassoCV                                                                     0.96
# ElasticNetCV                                                                0.96
# GradientBoostingRegressor                                                   0.97
# HuberRegressor                                                              0.97
# Ridge                                                                       0.97
# MLPRegressor                                                                0.97
# LinearSVR                                                                   0.98
# LinearRegression                                                            0.98
# TransformedTargetRegressor                                                  0.98
# XGBRegressor                                                                0.98
# GaussianProcessRegressor                                                    0.98
# ExtraTreesRegressor                                                         0.98
# ExtraTreeRegressor                                                          0.98
# DecisionTreeRegressor                                                       0.98
#
#                                                                      RMSE  \
# Model
# Lars                          9912289744152718910848349669234143395840.00
# KernelRidge                                                          4.74
# DummyRegressor                                                       0.94
# LassoLars                                                            0.94
# Lasso                                                                0.94
# ElasticNet                                                           0.94
# LarsCV                                                               0.82
# OrthogonalMatchingPursuitCV                                          0.79
# LassoLarsCV                                                          0.65
# KNeighborsRegressor                                                  0.54
# HistGradientBoostingRegressor                                        0.53
# LGBMRegressor                                                        0.53
# BayesianRidge                                                        0.50
# NuSVR                                                                0.47
# GammaRegressor                                                       0.47
# TweedieRegressor                                                     0.47
# SVR                                                                  0.47
# OrthogonalMatchingPursuit                                            0.37
# AdaBoostRegressor                                                    0.37
# BaggingRegressor                                                     0.34
# PoissonRegressor                                                     0.33
# SGDRegressor                                                         0.33
# RidgeCV                                                              0.31
# RandomForestRegressor                                                0.30
# PassiveAggressiveRegressor                                           0.25
# LassoCV                                                              0.18
# ElasticNetCV                                                         0.18
# GradientBoostingRegressor                                            0.17
# HuberRegressor                                                       0.17
# Ridge                                                                0.17
# MLPRegressor                                                         0.16
# LinearSVR                                                            0.13
# LinearRegression                                                     0.13
# TransformedTargetRegressor                                           0.13
# XGBRegressor                                                         0.13
# GaussianProcessRegressor                                             0.13
# ExtraTreesRegressor                                                  0.13
# ExtraTreeRegressor                                                   0.13
# DecisionTreeRegressor                                                0.13
#
#                                Time Taken
# Model
# Lars                                 0.15
# KernelRidge                          0.03
# DummyRegressor                       0.04
# LassoLars                            0.04
# Lasso                                0.02
# ElasticNet                           0.03
# LarsCV                               0.33
# OrthogonalMatchingPursuitCV          0.03
# LassoLarsCV                          0.12
# KNeighborsRegressor                  0.08
# HistGradientBoostingRegressor        0.12
# LGBMRegressor                        0.12
# BayesianRidge                        0.04
# NuSVR                                0.02
# GammaRegressor                       0.25
# TweedieRegressor                     0.04
# SVR                                  0.04
# OrthogonalMatchingPursuit            0.02
# AdaBoostRegressor                    0.11
# BaggingRegressor                     0.04
# PoissonRegressor                     0.22
# SGDRegressor                         0.04
# RidgeCV                              0.03
# RandomForestRegressor                0.26
# PassiveAggressiveRegressor           0.02
# LassoCV                              4.55
# ElasticNetCV                         7.24
# GradientBoostingRegressor            0.15
# HuberRegressor                       0.06
# Ridge                                0.02
# MLPRegressor                         0.17
# LinearSVR                            0.12
# LinearRegression                     0.04
# TransformedTargetRegressor           0.04
# XGBRegressor                         0.16
# GaussianProcessRegressor             0.03
# ExtraTreesRegressor                  0.27
# ExtraTreeRegressor                   0.04
# DecisionTreeRegressor                0.05

# %%
predictions_test
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          19491812649502393499708013038291839767374640219...
# TransformedTargetRegressor                             5381736967236604657664.00
# LinearRegression                                       5381736967236604657664.00
# GaussianProcessRegressor                                                    4.02
# KernelRidge                                                                 3.43
# OrthogonalMatchingPursuit                                                   1.18
# MLPRegressor                                                                1.18
# DummyRegressor                                                              1.13
# LassoLars                                                                   1.13
# Lasso                                                                       1.13
# ElasticNet                                                                  1.13
# DecisionTreeRegressor                                                       1.12
# ExtraTreeRegressor                                                          1.11
# OrthogonalMatchingPursuitCV                                                 1.11
# LarsCV                                                                      1.11
# LinearSVR                                                                   1.11
# LassoCV                                                                     1.08
# HuberRegressor                                                              1.08
# Ridge                                                                       1.06
# ElasticNetCV                                                                1.06
# LassoLarsCV                                                                 1.06
# ExtraTreesRegressor                                                         1.05
# PassiveAggressiveRegressor                                                  1.05
# XGBRegressor                                                                1.05
# GradientBoostingRegressor                                                   1.03
# RandomForestRegressor                                                       1.03
# BaggingRegressor                                                            1.03
# SGDRegressor                                                                1.03
# LGBMRegressor                                                               1.03
# HistGradientBoostingRegressor                                               1.03
# NuSVR                                                                       1.02
# SVR                                                                         1.02
# KNeighborsRegressor                                                         1.02
# AdaBoostRegressor                                                           1.02
# RidgeCV                                                                     1.02
# PoissonRegressor                                                            1.02
# GammaRegressor                                                              1.01
# BayesianRidge                                                               1.01
# TweedieRegressor                                                            1.01
#
#                                                                        R-Squared  \
# Model
# Lars                          -1926249720656707197215114536081417336880467695...
# TransformedTargetRegressor                           -53184224146808798969856.00
# LinearRegression                                     -53184224146808798969856.00
# GaussianProcessRegressor                                                  -28.84
# KernelRidge                                                               -23.05
# OrthogonalMatchingPursuit                                                  -0.83
# MLPRegressor                                                               -0.73
# DummyRegressor                                                             -0.31
# LassoLars                                                                  -0.31
# Lasso                                                                      -0.31
# ElasticNet                                                                 -0.30
# DecisionTreeRegressor                                                      -0.21
# ExtraTreeRegressor                                                         -0.11
# OrthogonalMatchingPursuitCV                                                -0.09
# LarsCV                                                                     -0.08
# LinearSVR                                                                  -0.08
# LassoCV                                                                     0.17
# HuberRegressor                                                              0.25
# Ridge                                                                       0.38
# ElasticNetCV                                                                0.39
# LassoLarsCV                                                                 0.43
# ExtraTreesRegressor                                                         0.50
# PassiveAggressiveRegressor                                                  0.51
# XGBRegressor                                                                0.53
# GradientBoostingRegressor                                                   0.66
# RandomForestRegressor                                                       0.66
# BaggingRegressor                                                            0.66
# SGDRegressor                                                                0.71
# LGBMRegressor                                                               0.75
# HistGradientBoostingRegressor                                               0.75
# NuSVR                                                                       0.76
# SVR                                                                         0.76
# KNeighborsRegressor                                                         0.76
# AdaBoostRegressor                                                           0.77
# RidgeCV                                                                     0.79
# PoissonRegressor                                                            0.79
# GammaRegressor                                                              0.86
# BayesianRidge                                                               0.87
# TweedieRegressor                                                            0.88
#
#                                                                             RMSE  \
# Model
# Lars                          13233035066839198288810059105452405762281086893...
# TransformedTargetRegressor                                       219884483139.02
# LinearRegression                                                 219884483139.02
# GaussianProcessRegressor                                                    5.21
# KernelRidge                                                                 4.68
# OrthogonalMatchingPursuit                                                   1.29
# MLPRegressor                                                                1.25
# DummyRegressor                                                              1.09
# LassoLars                                                                   1.09
# Lasso                                                                       1.09
# ElasticNet                                                                  1.09
# DecisionTreeRegressor                                                       1.05
# ExtraTreeRegressor                                                          1.00
# OrthogonalMatchingPursuitCV                                                 1.00
# LarsCV                                                                      0.99
# LinearSVR                                                                   0.99
# LassoCV                                                                     0.87
# HuberRegressor                                                              0.82
# Ridge                                                                       0.75
# ElasticNetCV                                                                0.74
# LassoLarsCV                                                                 0.72
# ExtraTreesRegressor                                                         0.68
# PassiveAggressiveRegressor                                                  0.67
# XGBRegressor                                                                0.65
# GradientBoostingRegressor                                                   0.56
# RandomForestRegressor                                                       0.55
# BaggingRegressor                                                            0.55
# SGDRegressor                                                                0.52
# LGBMRegressor                                                               0.48
# HistGradientBoostingRegressor                                               0.48
# NuSVR                                                                       0.47
# SVR                                                                         0.47
# KNeighborsRegressor                                                         0.46
# AdaBoostRegressor                                                           0.46
# RidgeCV                                                                     0.44
# PoissonRegressor                                                            0.43
# GammaRegressor                                                              0.35
# BayesianRidge                                                               0.34
# TweedieRegressor                                                            0.34
#
#                                Time Taken
# Model
# Lars                                 0.08
# TransformedTargetRegressor           0.03
# LinearRegression                     0.06
# GaussianProcessRegressor             0.03
# KernelRidge                          0.02
# OrthogonalMatchingPursuit            0.04
# MLPRegressor                         0.43
# DummyRegressor                       0.05
# LassoLars                            0.06
# Lasso                                0.03
# ElasticNet                           0.03
# DecisionTreeRegressor                0.05
# ExtraTreeRegressor                   0.02
# OrthogonalMatchingPursuitCV          0.07
# LarsCV                               0.36
# LinearSVR                            0.12
# LassoCV                              5.23
# HuberRegressor                       0.06
# Ridge                                0.03
# ElasticNetCV                         6.76
# LassoLarsCV                          0.16
# ExtraTreesRegressor                  0.24
# PassiveAggressiveRegressor           0.04
# XGBRegressor                         0.15
# GradientBoostingRegressor            0.16
# RandomForestRegressor                0.25
# BaggingRegressor                     0.06
# SGDRegressor                         0.04
# LGBMRegressor                        0.08
# HistGradientBoostingRegressor        0.11
# NuSVR                                0.04
# SVR                                  0.04
# KNeighborsRegressor                  0.02
# AdaBoostRegressor                    0.17
# RidgeCV                              0.04
# PoissonRegressor                     0.38
# GammaRegressor                       0.27
# BayesianRidge                        0.05
# TweedieRegressor                     0.13

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_test)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_test)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('finalfordataset.csv')

X = pd.DataFrame(X)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)



# Create a decision tree regressor model
tree_regressor = DecisionTreeRegressor(max_depth=3)

# Train the model on the training data
tree_regressor.fit(X_train, Y_train)

# Make predictions on the test data
Y_pred = tree_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
print(f'Mean Squared Error: {mse}')

from sklearn.metrics import explained_variance_score
evs = explained_variance_score(Y_test, Y_pred)
print(f'Explained Variance Score: {evs}')

from sklearn.metrics import r2_score
r2 = r2_score(Y_test, Y_pred)
print(f'R-squared: {r2}')

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test, Y_pred)
print(f'Mean Absolute Error: {mae}')

# Visualize the decision tree
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))
plot_tree(tree_regressor, filled=True, feature_names=X.columns)
plt.show()
# Out:
# Mean Squared Error: 0.5225280262191551
# Explained Variance Score: 0.45094985487565886
# R-squared: 0.4252178782832844
# Mean Absolute Error: 0.5294409712779581
